# %% [markdown]
# machine learning teaser
# X , y , linear regression y = a1*x1 + a2*x2 + a3

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.DataFrame([[100,70,30],
[120,80,40],
[150,100,50],
[180,120,60],
[200,130,70]],columns = ['selling_price','cost_price','profit'])

# %%
df.head()
# Out:
#    selling_price  cost_price  profit
# 0            100          70      30
# 1            120          80      40
# 2            150         100      50
# 3            180         120      60
# 4            200         130      70

# %%
X = df[['selling_price','cost_price']]
X
# Out:
#    selling_price  cost_price
# 0            100          70
# 1            120          80
# 2            150         100
# 3            180         120
# 4            200         130

# %%
y = df[['profit']]
y
# Out:
#    profit
# 0      30
# 1      40
# 2      50
# 3      60
# 4      70

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[ 1., -1.]])

# %%
model.intercept_
# Out:
# array([-4.26325641e-14])

# %%
model.predict([[300,200]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[100.]])

# %%
# !pip install numpy

# %%
# !pip install pandas

# %%
model2 = PolynomialRegression()

# %%
model2.fit(X,y)

# %%
model2.coef_
